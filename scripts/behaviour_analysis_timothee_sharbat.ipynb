# %% [markdown]
# # Setup
# Trying to import the different runs individually, starting with documentation from Timothee

# %%
import pandas as pd
import os
import re
from matplotlib import cm 
import matplotlib.pyplot as plt 
from scipy import stats
import numpy as np
import itertools
import src.compute_data_auto as cda

plt.style.use('../anemotaxis.mplstyle')

# %%
# %matplotlib widget
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Variables
# Check what are the required variables

# %%
min_t,max_t,step_t = 5,600,5
min_to,max_to,step_to = 60,602,5

# %%
#Path where the procressed data are stored
data_path = "/mnt/c/Users/schatterjee/Documents/anemotaxis/data/20210803_112230/"

# %% [markdown]
# ## Test data

# %%
name_columns = ["time","speed","length","curvature"]

# %%
cda.chore_all(data_path)
# Out:
#  :  Already analysed

# %%
cda.run_compute(path_data=data_path, name_columns=name_columns, save_folder=data_path)
# Out:
#  :  Already analysed
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 cda.run_compute(path_data=data_path, name_columns=name_columns, save_folder=data_path)
#
# File /mnt/c/Users/schatterjee/Documents/anemotaxis/src/compute_data_auto.py:240, in run_compute(path_data, name_columns, save_folder)
#     237 chore_all(path_data)
#     239 #Save everything
# --> 240 all_concatenate_save(path_data,name_columns,save_folder)
#
# File /mnt/c/Users/schatterjee/Documents/anemotaxis/src/compute_data_auto.py:220, in all_concatenate_save(path_data, name_columns, save_folder)
#     210 """Function that concatenate all the data for each experiments and save the computed (.json) file in the save_folder
#     211
#     212 Args:
#    (...)
#     215     save_folder (str): path of the folder to save the computed .json files
#     216 """
#     217 # list_path_exp = retrieve_path_exp(path_data)
#     218 # list_path_exp = [path_data + "/" + path_exp for path_exp in list_path_exp]
#     219 # for path in list_path_exp :
# --> 220 concatenate_and_save(path_data,name_columns,save_folder)
#
# File /mnt/c/Users/schatterjee/Documents/anemotaxis/src/compute_data_auto.py:35, in timeit.<locals>.timeit_wrapper(*args, **kwargs)
#      32 @wraps(func)
#      33 def timeit_wrapper(*args, **kwargs):
#      34     start_time = time.perf_counter()
# ---> 35     result = func(*args, **kwargs)
#      36     end_time = time.perf_counter()
#      37     total_time = end_time - start_time
#
# File /mnt/c/Users/schatterjee/Documents/anemotaxis/src/compute_data_auto.py:153, in concatenate_and_save(experiment_path, name_columns, save_folder)
#     144 """Function that retrieve the data for on experiement and save it at the desired location as a json file
#     145
#     146 Args:
#    (...)
#     150
#     151 """
#     152 list_path_dat = list_dat(experiment_path)
# --> 153 dict_expe = dict_expe_(experiment_path)
#     155 #To produce each dataframe
#     156 def read_csv_format(path_dat):
#
# File /mnt/c/Users/schatterjee/Documents/anemotaxis/src/compute_data_auto.py:91, in dict_expe_(experiment_path)
#      89 list_ = common.split("@")
#      90 list_.remove(list_[-1]) #We don't care about the last element
# ---> 91 dict_expe = {"date" : list_[0], "genotype" : list_[1],"effector" : list_[2],"tracker" : list_[3], "protocol" : list_[4]}
#      92 return dict_expe
#
# IndexError: list index out of range

# %%
#Retrieve all the metadata from this folder

def meta_one_file(file):
    meta = file.split("@")
    genotype = meta[0]
    effector = meta[1]
    date = meta[2]
    date = re.sub(r'.json',"",date) 
    return genotype,effector,date

#To be able to see what we have in the folder

set_genotypes = set()
set_effectors = set()
set_dates = set()

list_files = os.listdir(data_path)

for file in list_files :
    ext = os.path.splitext(file)[1]
    if ext == ".json" :
        genotype,effector,date = meta_one_file(file)   
        set_genotypes.add(genotype)
        set_effectors.add(effector)
        date = re.sub(r'_[0-9]{6}',"",date)
        set_dates.add(date)
    else:
        print(file, " why not JSON ?")
# Out:
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.00001.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.00003.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.00005.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.00006.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.00007.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.00009.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.00010.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.00013.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.00015.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.00016.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.00017.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.00020.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.00021.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.00022.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.00023.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.00024.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.00025.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.00026.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.00027.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.00046.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.00050.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.00060.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.00161.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.00174.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.00175.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.00178.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.00179.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.00181.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.00184.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.00185.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.00191.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.00205.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.00243.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.00244.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.00246.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.00250.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.00255.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.00271.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.00279.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.00290.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.00306.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.00317.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.00340.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.00354.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.00376.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.00390.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.00441.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.00442.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.00456.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.00479.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.00526.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.00541.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.00555.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.00556.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.00557.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.00589.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.00590.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.00833.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.00834.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.00966.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.00970.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.00971.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.01086.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.01090.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.01168.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.01183.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.01247.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.01248.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.01289.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.01305.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.01322.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.01352.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.01390.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.01431.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.01432.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.01521.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.01635.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.01691.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.01777.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.01801.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.01802.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.01873.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.02071.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.02105.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.02106.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.02134.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.02135.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.02136.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.02161.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.02320.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.02352.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.02427.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.02462.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.02587.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.02680.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.02681.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.02721.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.02786.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.02893.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.02894.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.02994.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.02995.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.03035.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.03189.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.03190.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.03237.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.03238.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.03264.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.03458.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.03467.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.03468.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.03509.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.03551.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.03577.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.03617.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.03618.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.03678.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.03712.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.03780.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.03800.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.03898.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.03926.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.03927.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.03949.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.04002.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.04113.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.04193.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.04239.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.04303.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.04304.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.04325.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.04344.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.04345.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.04417.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.04486.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.04580.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.04609.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.04620.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.04654.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.04671.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.04698.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.04760.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.04777.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.04793.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.04795.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.04820.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.04822.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.04823.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.04832.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.04833.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.04878.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.04921.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.04945.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.04946.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.04949.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.04950.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.04973.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.04974.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.04990.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.04991.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.05046.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.05138.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.05139.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.05258.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.05272.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.05280.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.05281.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.05534.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.05554.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.05625.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.05643.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.05644.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.05680.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.05715.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.05719.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.05787.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.05788.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.05799.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.05845.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.05866.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.05867.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.05906.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.05926.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.06010.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.06011.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.06129.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.06152.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.06153.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.06195.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.06218.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.06282.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.06283.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.06314.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.06375.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.06403.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.06414.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.06415.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.06491.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.06492.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.06502.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.06522.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.06525.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.06540.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.06549.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.06564.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.06574.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.06609.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.06638.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.06639.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.06643.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.06673.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.06721.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.06722.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.06781.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.06815.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.06845.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.06904.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.06919.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.06929.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.06947.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.07043.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.07126.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.07127.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.07145.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.07188.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.07211.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.07212.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.07264.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.07277.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.07339.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.07365.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.07451.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.07529.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.07530.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.07578.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.07579.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.07581.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.07607.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.07887.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.07890.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.07943.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.08009.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.08085.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.08141.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.08142.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.08208.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.08209.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.08275.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.08292.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.08366.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.08506.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.08541.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.08542.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.08563.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.08564.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.08614.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.08615.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.08616.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.08738.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.08739.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.08755.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.08760.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.08766.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.08768.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.08791.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.08811.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.08840.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.08842.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.08853.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.08855.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.08862.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.08883.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.08897.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.08902.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.08903.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.08918.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.08926.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.08932.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.08938.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.08976.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.08990.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.09006.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.09008.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.09033.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.09072.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.09101.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.09109.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.09110.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.09125.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.09130.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.09191.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.09194.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.09240.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.09264.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.09272.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.09313.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.09314.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.09457.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.09472.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.09576.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.09590.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.09611.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.09625.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.09657.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.09704.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.09780.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.09817.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.09819.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.09827.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.09848.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.09937.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.10004.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.10059.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.10075.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.10103.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.10153.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.10346.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.10374.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.10375.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.10411.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.10475.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.10527.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.10558.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.10713.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.10719.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.10790.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.10795.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.10796.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.11016.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.11180.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.11641.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.11736.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.11758.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.11878.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.12034.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.12147.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.12280.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.12281.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.12442.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.12471.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.12472.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.12513.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.12528.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.12550.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.12585.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.12603.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.12780.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.12808.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.12903.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.12960.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.13160.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.13161.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.13216.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.13228.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.13586.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.13587.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.13604.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.13669.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.13737.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.13828.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.13829.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.13856.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.14039.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.14173.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.14308.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.14648.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.14666.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.14814.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.15159.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.15273.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.15274.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.15791.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.16006.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.16120.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.16176.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.16177.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.16271.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.16371.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.16752.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.16944.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.16962.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.16963.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.17118.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.17134.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.17168.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.17192.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.17193.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.17256.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.17544.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.17573.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.17645.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.17646.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.17780.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.18202.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.18516.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.18669.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.18841.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.19082.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.19233.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.19343.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.19415.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.19507.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.19603.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.19990.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.20000.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.20001.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.20094.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.20198.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.20237.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.20965.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.21004.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.21005.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.21023.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.21024.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.21051.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.21072.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.21236.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.21237.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.21261.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.21461.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.21691.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.21713.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.21714.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.21915.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.21916.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.21933.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.21934.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.22265.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.22382.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.22541.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.22542.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.22709.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.23052.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.23416.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.23528.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.23534.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.23609.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.23626.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.23896.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.23920.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.24008.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.24046.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.24082.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.24263.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.24408.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.24566.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.24886.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.24933.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.25029.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.25080.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.25081.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.25147.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.25274.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.25275.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.25380.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.25419.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.25432.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.25482.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.25537.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.25538.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.25632.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.25633.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.dat  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.outline  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.png  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.set  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.spine  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20.summary  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20_00000k.blobs  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20_00001k.blobs  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20_00002k.blobs  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20_00003k.blobs  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20_00004k.blobs  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20_00005k.blobs  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20_00006k.blobs  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20_00007k.blobs  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20_00008k.blobs  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20_00009k.blobs  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20_00010k.blobs  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20_00011k.blobs  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20_00012k.blobs  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20_00013k.blobs  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20_00014k.blobs  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20_00015k.blobs  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20_00016k.blobs  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20_00017k.blobs  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20_00018k.blobs  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20_00019k.blobs  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20_00020k.blobs  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20_00021k.blobs  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20_00022k.blobs  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20_00023k.blobs  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20_00024k.blobs  why not JSON ?
# 20210803_112230@CSMH@CSMH@t7@p_5gradient2_2s1x600s0s#n#n#n@20_00025k.blobs  why not JSON ?
# trx.mat  why not JSON ?

# %%
# Display the metadata
print("Genotypes : ",set_genotypes)
print("Effectors : ",set_effectors)
print("Dates  : ",set_dates)
# Out:
# Genotypes :  {'CSMH'}
# Effectors :  {'CSMH'}
# Dates  :  {'20210803'}

# %%
#Final dict with all the raw data
raw_data = dict()

#Setting the structure of the dictionnary
for genotype in set_genotypes:
    raw_data[genotype] = dict()

#Importing the data : 

for file in list_files : 
    if os.path.splitext(file)[1] == ".json":
        genotype,effector,date = meta_one_file(file)
        #if not "20240226" in date :
        path = data_path + "/" + file
        data_file = pd.read_json(path)
        raw_data[genotype][date] = data_file
    else : continue

# %%
print(raw_data['CSMH']['20210803_112230'].keys())
# Out:
# Index(['time', 'speed', 'length', 'curvature'], dtype='object')

# %% [markdown]
# # Useful functions

# %%
##split the data of the different larvae for 1 experiment
#Reminder : 1 experiment is saved as a dataframe of the concatenated dataframes for each larvae

def split_exp_to_larvae(data_exp):
    """Function that take for input the concatenated data of 1 experiment and output a dictionary which contains the data for each larva separetely 

    Args:
        data_exp (pd.Dataframe): Dataframe of the concatenated data

    Returns:
        dict: dictionnary of the separated larvae data. Each items if a dataframe of the data for 1 larvae
    """
    dict_exp = {} #Dictionnary that will contain all the different larvae (keys = id of the larvae)
    
    #To retriveve all the IDs of the larvae for this exp
    ID_larvae = set(data_exp["id"])
    #print(ID_larvae)
    
    for _id in ID_larvae:
        #print("ID : ",_id)
        data_larva = data_exp[data_exp["id"] == _id]
        dict_exp[_id] = data_larva
    
    return dict_exp

# %%
raw_data['CSMH']['20210803_112230']['time'].shape
# Out:
# (429830,)

# %%
fig = plt.figure(figsize=(10,5))
plt.plot(raw_data['CSMH']['20210803_112230']['time'][10:], raw_data['CSMH']['20210803_112230']['speed'][10:])
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
#Function to format the raw data to have independent data for each larvae

def split_larvae_all(raw_data):
    split_raw_data = dict()
    for genotype,dict_df in raw_data.items():
        dict_split_exp = dict()
        for date,df_exp in dict_df.items():
            dict_split = split_exp_to_larvae(df_exp)
            dict_split_exp[date] = dict_split
        split_raw_data[genotype] = dict_split_exp
    return split_raw_data

# %%
# split_raw_data = split_larvae_all(raw_data)

# %%
# print(split_raw_data["CSMH"].keys())
# print(split_raw_data["CSMH"]["20210803_112230"]

# %%
raw_data['CSMH']['20210803_112230']['time']
# Out:
# dict_keys([2.125, 2.878, 5.5120000000000005, 5.119, 7.7379999999999995, 8.518, 8.850999999999999, 9.607, 11.003, 9.997, 13.741, 14.857, 14.271, 16.009, 17.039, 17.515, 19.107, 20.726, 20.976, 22.006, 23.101, 24.798000000000002, 25.03, 26.524, 18.217, 28.375, 29.798000000000002, 21.342, 31.006, 31.726, 32.452, 33.601, 35.048, 34.298, 35.851, 36.952, 37.202, 40.024, 41.027, 38.572, 43.038, 41.197, 45.048, 46.053, 44.875, 48.179, 49.039, 45.298, 51.024, 50.798, 53.042, 54.012, 55.018, 56.051, 51.476, 51.928, 59.044, 60.021, 61.044, 61.943, 63.032, 64.041, 65.043, 65.961, 67.356, 64.762, 68.53, 68.588, 62.167, 63.256, 64.1, 65.154, 66.018, 67.025, 68.142, 69.038, 70.042, 71.047, 72.059, 73.031, 74.007, 75.049, 76.042, 77.019, 78.0, 79.033, 80.015, 81.012, 82.021, 83.053, 84.034, 85.064, 86.015, 87.021, 88.054, 89.035, 90.039, 91.043, 94.032, 95.009, 96.066, 97.019, 98.022, 99.001, 100.035, 101.039, 102.016, 103.025, 104.005, 105.01, 106.016, 107.037, 108.05, 109.029, 110.034, 111.008, 113.019, 114.028, 115.029, 116.032, 117.012, 118.049, 119.056, 120.034, 121.01, 123.047, 124.051, 125.021, 126.027, 127.043, 128.019, 129.022, 130.028, 131.058, 132.017, 133.01, 134.016, 135.028, 136.036, 137.035, 138.05, 139.026, 140.026, 141.055, 142.009, 143.044, 144.021, 145.0, 146.003, 148.039, 149.048, 150.053, 151.001, 152.003, 154.022, 155.02, 156.034, 157.012, 159.042, 160.052, 161.056, 162.003, 164.019, 165.022, 166.023, 167.006, 169.014, 170.047, 171.045, 172.031, 164.601, 174.013, 175.046, 176.053, 177.03, 169.265, 179.069, 180.071, 181.049, 182.028, 174.188, 184.007, 185.046, 186.021, 187.054, 188.032, 189.014, 190.044, 191.049, 192.052, 193.029, 194.041, 195.01, 196.021, 197.055, 189.149, 199.038, 200.038, 201.009, 202.052, 203.025, 204.058, 205.014, 206.049, 207.05, 208.029, 209.04, 210.031, 211.041, 212.047, 204.231, 214.005, 215.009, 216.044, 217.025, 209.788, 219.027, 220.061, 221.037, 222.021, 223.048, 224.053, 225.039, 226.013, 227.042, 228.049, 229.029, 230.006, 231.008, 232.014, 233.075, 234.051, 235.033, 236.012, 236.508, 238.024, 239.024, 240.031, 241.034, 242.016, 234.11, 244.022, 245.031, 246.037, 247.013, 239.586, 240.202, 250.054, 251.036, 252.009, 244.14, 245.336, 255.033, 256.03, 257.039, 258.772, 258.405, 260.001, 261.036, 262.009, 260.862, 264.469, 261.731, 266.004, 53.875, 267.009, 268.014, 269.051, 270.051, 271.058, 272.03, 273.041, 274.028, 275.024, 276.057, 277.015, 279.044, 280.05, 281.027, 282.031, 283.011, 284.042, 285.053, 286.0, 287.033, 288.007, 289.011, 290.019, 291.055, 292.03, 284.488, 294.012, 295.013, 296.001, 289.765, 290.658, 294.265, 293.318, 295.541, 295.862, 294.071, 295.073, 296.074, 297.034, 298.036, 299.037, 300.042, 301.021, 302.03, 303.032, 304.06, 305.017, 306.027, 307.027, 308.004, 309.043, 310.044, 311.045, 312.025, 313.036, 64.346, 315.042, 316.013, 317.022, 318.032, 319.005, 320.01, 321.019, 322.021, 323.029, 324.006, 325.013, 326.018, 327.026, 328.002, 67.471, 330.038, 331.046, 332.049, 333.056, 334.001, 335.063, 336.014, 337.073, 338.052, 339.029, 340.032, 341.037, 342.023, 343.029, 344.033, 345.038, 346.024, 347.016, 348.05, 349.036, 350.04, 351.066, 352.014, 353.02, 354.0, 355.037, 356.038, 357.046, 358.05, 359.055, 360.004, 361.008, 362.068, 363.027, 364.03, 365.034, 366.035, 367.017, 368.072, 369.052, 370.0, 371.035, 372.038, 373.021, 374.022, 375.024, 376.033, 377.065, 378.07, 77.75, 380.051, 381.01, 382.042, 383.045, 78.279, 385.026, 386.002, 387.03, 388.042, 79.846, 390.054, 391.023, 392.013, 393.039, 80.654, 395.052, 396.001, 397.037, 398.008, 399.014, 400.027, 401.004, 402.004, 403.039, 82.471, 82.529, 82.721, 407.032, 408.038, 409.039, 410.056, 411.055, 412.008, 413.035, 414.038, 415.05, 416.025, 417.036, 418.039, 419.013, 420.046, 421.058, 422.025, 423.055, 86.721, 425.019, 426.021, 427.049, 428.009, 429.042, 430.017, 431.001, 432.063, 433.058, 88.471, 435.048, 436.048, 437.058, 438.032, 439.009, 440.017, 441.023, 442.019, 443.007, 90.154, 445.04, 446.013, 447.052, 448.035, 44 ...

# %%
# Navigationnal index from data of 1 larva 

def NI_ind(data_ind, ax="x"): 
    """Function that compute the navigationnal index (normalized or not) for 1 larva

    Args:
        data_ind (pd.Dataframe): data for 1 larvae
        ax (str, optional): Axis along which we compute the NI. Defaults to "x".
    
    Returns:
        dict : THe values of the normalized and not normalized navigationnal index
    """
    #Retrieve the interesting data 
    axis = "vel_x" if ax=="x" else "vel_y"
    vel_axis = data_ind[axis]
    speed = data_ind["speed"]
    midline = data_ind["midline"].mean() #Mean of the midline ? 
    
    #Normalize
    norm_vel = vel_axis / midline
    norm_speed = speed / midline
    
    #means
    mean_vel = vel_axis.mean()
    mean_vel_norm = norm_vel.mean()
    mean_speed = speed.mean()
    mean_speed_norm = norm_speed.mean()
    
    #NI 
    #NI = mean_vel/mean_speed
    NI = vel_axis/speed
    NI = NI.mean()
    NI_norm = NI/midline
    dict_NI = {"NI" : NI,"NI_norm": NI_norm}
    
    return dict_NI

# %%
#To see the number of larvae for each experiments
for genotype,dict_genotype in split_raw_data.items():
    print("\n _________________ \n")
    print(genotype,": \n")
    total = 0
    for date,exp in dict_genotype.items():
        nb_larvae = len(exp)
        total +=nb_larvae
        print(date, " : ", nb_larvae)
    print("Total : ",total)

# %% [markdown]
# ******

# %%
dict_persistency = dict()
for genotype,dict_gen in split_raw_data.items():
    df_gen = pd.DataFrame()
    for exp,data_exp in dict_gen.items():
        for larva,df_larva in data_exp.items():
            persistency = df_larva["persitence"].max()
            persistency_larva = pd.DataFrame({"id" : larva,"date" : exp,"persistence" : persistency},index=[0])
            df_gen = pd.concat([df_gen,persistency_larva])
    dict_persistency[genotype] = df_gen

# %%
dict_persistency

# %%
fig, axes = plt.subplots(4,3,figsize = (20,20))
for ind,(genotype,data_persistency) in enumerate(dict_persistency.items()):
    row,col = divmod(ind,3)
    axes[row,col].set_title(genotype)
    data_persistency["persistence"].plot(kind="hist",ax=axes[row,col],bins = 30)

# %%
for genotype,df in dict_persistency.items():
    print(genotype, ': ')
    nb_sup_300 = len(df[df["persistence"] > 500])
    total = len(df)
    perc = nb_sup_300 / total
    print("{} Larvae with tracks sup than 300 over {} so : {} %".format(nb_sup_300,total,perc))
    print("\n ___ ")

# %%
lim_t = 305
for genotype,df in dict_persistency.items():
    print(genotype, ': ')
    dates = set(df["date"])
    for date in dates: 
        data_date = df[df["date"] == date]
        nb_sup_300 = len(data_date[data_date["persistence"] > lim_t])
        total = len(data_date)
        perc = nb_sup_300 / total
        print("{} larvae over {} so : {} %".format(nb_sup_300,total,perc))
    print("\n ___ ")

# %%
DF_PERSISTENCY = pd.DataFrame()
for genotype,df_persistence in dict_persistency.items():
    ser_name = pd.Series([genotype for i in range(len(df_persistence))])
    df_persistence["genotype"]=ser_name
    #print(df_persistence)
    DF_PERSISTENCY = pd.concat([DF_PERSISTENCY,df_persistence])
DF_PERSISTENCY

# %%
DF_PERSISTENCY["persistence"].plot(kind= "hist",bins=20)

# %%
df_time = pd.DataFrame()
for genotype,dict_gen in split_raw_data.items(): 
    for exp,dict_exp in dict_gen.items():
        for id_larva, df_larva in dict_exp.items():
            NIx = NI_ind(df_larva,ax="x")["NI"]
            NIy = NI_ind(df_larva,ax="y")["NI"]
            end_time = df_larva["time"].max()
            start_time = df_larva["time"].min()
            comp_pers = end_time-start_time
            pers = df_larva["persitence"]
            mem = exp.split("_")
            date = mem[0]
            time = mem[1]
            line_larva = pd.DataFrame({"id" : [id_larva],
                                       "date" : [date],
                                       "time" : [time], 
                                       "genotype" : [genotype],
                                       "start_time": [start_time],
                                       "end_time" : [end_time],
                                       "comp_pers" : [comp_pers],
                                       "NIx" : [NIx],
                                       "NIy" : [NIy]
                                       })
            df_time = pd.concat([df_time,line_larva],ignore_index=True)

# %%
df_time[~(df_time["genotype"]=="FCF_attP2-40")]["end_time"].plot(kind = 'hist',bins = 20)

# %% [markdown]
# Index that might be interesting to test :
# Let's have for larva $i \in \llbracket 1,n \rrbracket$, $s_i$ defined as : $$ S_i = \frac{T - s_i}{T}$$
# with $T = \max( \{t_{i,j}\}_{i,j \in \llbracket 1,k \rrbracket \times \llbracket 1,n \rrbracket})$ the maximum value of time of tracked object, $s_i = \min ( \{t_j\}_{j \in \llbracket 1,k \rrbracket})$ the start time of the tracking of the object :
#
# and $p_i$ : $$ p_i = \frac{e_i - s_i}{T} $$
# with $e_i = \max ( \{t_j\}_{j \in \llbracket 1,k \rrbracket})$

# %% [markdown]
# From here we can have : $$ P_i = p_i \times S_i $$
# This could quantify how much we can trust the choosen framing to compute navigationnal index

# %%
T = df_time["end_time"].max()
df_time

# %%
df_time.loc[df_time["genotype"] == "GMR_MB054B"]

# %%
df_time["s_i"] = (T - df_time["start_time"]) / T
df_time["p_i"] = df_time["comp_pers"] / T
df_time["P_i"] = df_time["s_i"] * df_time["p_i"]
df_time["P_i"].mean()

# %%
test = df_time.groupby("genotype").mean("P_i")
test = test["P_i"] 
test
n_genotype = df_time.groupby("genotype").count()
n_genotype = n_genotype['id']
n_genotype.name = "n"
test.mean()

# %% [markdown]
# If we compute : $$ \theta =  \alpha \lang P_i \rang_{i \in \llbracket 1,n \rrbracket} \times \beta \nu $$ we can have a function that link the number of larvae and the fidelity.
# To find the optimal framing we just need to find the maximum of this function with with different value of min time of persistency, and time
#
# $$ \nu = 1 - \frac{\max(n_{t,to}) - n_{t,to}}{\max(n_{t,to})} $$

# %%
def compute_theta_and_n(df_time):
    N = len(df_time)
    T = df_time["end_time"].max()
    df_time["s_i"] = (T - df_time["start_time"]) / T
    df_time["p_i"] = df_time["comp_pers"] / T
    df_time["P_i"] = df_time["s_i"] * df_time["p_i"]
    theta_genotype = df_time.groupby("genotype").mean("P_i")
    theta_genotype = theta_genotype["P_i"]
    
    n_genotype = df_time.groupby("genotype").count()
    n_genotype = n_genotype['id']
    n_genotype.name = "n"
    #n_genotype = (N - n_genotype)/N
    
    return theta_genotype,n_genotype

# %%
min_t,max_t,step_t = 5,600,5
min_to,max_to,step_to = 60,602,5 

arr_t = [str(t) for t in range(min_t,max_t,step_t)]
print(arr_t)
arr_to = [str(to) for to in range(min_to,max_to,step_to)]
print(arr_to)

DF_THETA = pd.DataFrame(columns = arr_t,index=arr_to)
DF_N = pd.DataFrame(columns = arr_t,index=arr_to)

for to in arr_to:
    iterator = itertools.filterfalse(lambda x: int(x) > int(to),arr_t)
    for t in iterator :
        df_time_truncated = df_time[df_time["comp_pers"] > int(t)]
        df_time_truncated = df_time_truncated[df_time_truncated["end_time"] > int(to)]
        theta_df,n_df = compute_theta_and_n(df_time_truncated)
        DF_THETA[t][to] = theta_df
        DF_N[t][to]= n_df

# %%
N = len(df_time)
DF_THETA_MEAN = pd.DataFrame(columns = arr_t,index=arr_to)
DF_N_MEAN = pd.DataFrame(columns = arr_t,index=arr_to)

for t in arr_t : 
    ind_not_null = ~pd.isnull(DF_THETA[t])
    for to in DF_THETA.index:
        if ind_not_null[to]:
            theta_mean = DF_THETA[str(t)][str(to)].mean()
            n_mean = DF_N[str(t)][str(to)].sum()
            #print(theta_mean)
            DF_THETA_MEAN[str(t)][str(to)] = theta_mean
            DF_N_MEAN[str(t)][str(to)] = 1- (N - n_mean)/N

# %%
arr_t_int = [t for t in range(min_t,max_t,step_t)]
arr_to_int = [to for to in range(min_to,max_to,step_to)]

X,Y = np.meshgrid(arr_t_int,arr_to_int)


fig, ax = plt.subplots(subplot_kw={"projection": "3d"})
surf = ax.plot_surface(X, Y, DF_N_MEAN, cmap=cm.coolwarm,
                       linewidth=0, antialiased=False)

# %%
DF_THETA_MEAN.to_json("/Users/timotheesanchez/Desktop/Behavior_analysis/data/DF_THETA_MEAN.json")
DF_N_MEAN.to_json("/Users/timotheesanchez/Desktop/Behavior_analysis/data/DF_N_MEAN.json")

# %%
def master_to_df_NI_per_genotype(df_time,ax="x"):
    axis = "NIx" if ax == "x" else "NIy"
    dict_NI_per_gen  = dict()
    genotypes = set(df_time["genotype"])
    #print(genotypes)
    for genotype in genotypes :
        DF_genotype = df_time[[axis,"id"]][df_time["genotype"] == genotype]
        DF_genotype = DF_genotype.reset_index(drop=True)
        dict_NI_per_gen[genotype] = DF_genotype
    
    DF_NI_per_gen = pd.DataFrame()
    for genotype,df_gen in dict_NI_per_gen.items():
        col_to_add = df_gen[axis]
        col_to_add.name = genotype
        DF_NI_per_gen= pd.concat([DF_NI_per_gen,col_to_add],axis=1)
    return DF_NI_per_gen

# %%
arr_t = [str(t) for t in range(min_t,max_t,step_t)]
#print(arr_t)
arr_to = [str(to) for to in range(min_to,max_to,step_to)]
#print(arr_to)

DF_NIx = pd.DataFrame(columns = arr_t,index=arr_to)
DF_NIy = pd.DataFrame(columns = arr_t,index=arr_to)

for to in arr_to:
    iterator = itertools.filterfalse(lambda x: int(x) > int(to),arr_t)
    for t in iterator :
        df_time_truncated = df_time[df_time["comp_pers"] > int(t)]
        df_time_truncated = df_time_truncated[df_time_truncated["end_time"] > int(to)]
        NIx_genotype = master_to_df_NI_per_genotype(df_time_truncated,ax = "x")
        NIy_genotype = master_to_df_NI_per_genotype(df_time_truncated,ax = "y")
        
        DF_NIx[t][to] = NIx_genotype
        DF_NIy[t][to]= NIy_genotype

# %%
def Kruskal_over_DF(DF_list_NI_per_gen):
    to_test = tuple(np.array(DF_list_NI_per_gen[name]) for name in DF_list_NI_per_gen.columns)
    result = stats.kruskal(*to_test,nan_policy='omit')
    return(result.pvalue)

# %%
def apply_NI(DF_TO_WORK,func,arr_t,arr_to,**kwarg):
    DF_OUTPUT = pd.DataFrame(columns = arr_t,index=arr_to)
    for t in arr_t : 
        ind_not_null = ~pd.isnull(DF_TO_WORK[t])
        for to in DF_TO_WORK.index:
            if ind_not_null[to]:
                df_per_gen = DF_TO_WORK[str(t)][str(to)]
                compressed_df = func(df_per_gen,**kwarg)
                DF_OUTPUT[str(t)][str(to)] = compressed_df
    return DF_OUTPUT

# %%
DF_KRUSKAL = apply_NI(DF_NIx,Kruskal_over_DF,arr_t,arr_to)

# %%
DF_KRUSKAL

# %%
DF_KRUSKAL.to_json("/Users/timotheesanchez/Desktop/Behavior_analysis/data/DF_KRUSKAL.json")

# %%
def truncater_df(df_time,gen_to_keep,date_to_keep):
    genotypes = set(df_time["genotype"])
    dates = set(df_time["date"])
    gen_to_remove = [gen for gen in genotypes if gen not in gen_to_keep]
    #print("gen to remove  : {}".format(gen_to_remove))
    date_to_remove = [date for date in dates if date not in date_to_keep]
    #print("date to remove  : {}".format(date_to_remove))
    df_time_trunc = df_time
    for date in date_to_remove :
        df_time_trunc = df_time_trunc[~(df_time_trunc["date"] == date)]
    for gen in gen_to_remove : 
        df_time_trunc = df_time_trunc[~(df_time_trunc["genotype"] == gen)]
    return df_time_trunc

# %%
def DF_NI_condition(df_time,date_to_select,genotype_to_select,arr_to,arr_t,axis):
    arr_t = [str(t) for t in range(min_t,max_t,step_t)]
    arr_to = [str(to) for to in range(min_to,max_to,step_to)]

    DF_OUTPUT = pd.DataFrame(columns = arr_t,index=arr_to)

    for to in arr_to:
        iterator = itertools.filterfalse(lambda x: int(x) > int(to),arr_t)
        for t in iterator :
            
            df_time_truncated = truncater_df(df_time,date_to_keep=date_to_select,gen_to_keep=genotype_to_select)
            df_time_truncated = df_time_truncated.loc[(df_time_truncated["comp_pers"] > int(t)) & (df_time_truncated["end_time"] > int(to))]
            #df_time_truncated = df_time_truncated[df_time_truncated["end_time"] > int(to)]
            
            NI_genotype = master_to_df_NI_per_genotype(df_time_truncated,ax = axis)
            
            DF_OUTPUT[t][to] = NI_genotype
    return(DF_OUTPUT)

# %%
set(df_time["date"])

# %%
gen_to_keep = ['FCF_attP2-40',
 'GMR_MB054B',
 'GMR_MB065B',
 'GMR_MB143B',
 'GMR_MB145B',
 'GMR_SS00864',
 'GMR_SS01696',
 'GMR_SS01716',
 'GMR_SS01757',
 'GMR_SS01948',
 'GMR_SS02160']

date_to_keep = ['20240219',
        '20240223',
        #'20240226',
        '20240301',
        '20240304',
        '20240308']

DF_NIx_wout_0226 = DF_NI_condition(df_time,date_to_keep,gen_to_keep,arr_to,arr_t,"x")

# %%
DF_KRUSKAL_NIx_wout_0226 = apply_NI(DF_NIx_wout_0226,Kruskal_over_DF,arr_t,arr_to)
DF_KRUSKAL_NIx_wout_0226

# %%
DF_KRUSKAL_NIy = apply_NI(DF_NIy,Kruskal_over_DF,arr_t,arr_to)

# %%
#DF_KRUSKAL_NIy.to_json("/Users/timotheesanchez/Desktop/Behavior_analysis/data/DF_KRUSKAL_NIy.json")
#DF_KRUSKAL_NIy_wout_0226.to_json("/Users/timotheesanchez/Desktop/Behavior_analysis/data/DF_KRUSKAL_NIx_wout0226.json")

# %%
gen_to_keep = ['FCF_attP2-40',
 'GMR_MB054B',
 'GMR_MB065B',
 'GMR_MB143B',
 'GMR_MB145B',
 'GMR_SS00864',
 'GMR_SS01696',
 'GMR_SS01716',
 'GMR_SS01757',
 'GMR_SS01948',
 'GMR_SS02160']

date_to_keep = ['20240219',
        '20240223',
        #'20240226',
        '20240301',
        '20240304',
        '20240308']

DF_NIy_wout_0226 = DF_NI_condition(df_time,date_to_keep,gen_to_keep,arr_to,arr_t,"y")
DF_KRUSKAL_NIy_wout_0226 = apply_NI(DF_NIy_wout_0226,Kruskal_over_DF,arr_t,arr_to)
DF_KRUSKAL_NIy_wout_0226.to_json("/Users/timotheesanchez/Desktop/Behavior_analysis/data/DF_KRUSKAL_NIy_wout0226.json")

# %%
gen_to_keep = ['FCF_attP2-40',
 'GMR_MB054B',
 'GMR_MB065B',
 'GMR_MB143B',
 'GMR_MB145B',
 'GMR_SS00864',
 'GMR_SS01696',
 'GMR_SS01716',
 'GMR_SS01757',
 'GMR_SS01948',
 'GMR_SS02160']

date_to_keep_list = ['20240219',
        '20240223',
        '20240226',
        '20240301',
        '20240304',
        '20240308']

for date in date_to_keep_list:
    date_to_keep = [date]
    DF_NIx = DF_NI_condition(df_time,date_to_keep,gen_to_keep,arr_to,arr_t,"y")
    DF_KRUSKAL_NIx = apply_NI(DF_NIx,Kruskal_over_DF,arr_t,arr_to)
    DF_KRUSKAL_NIx.to_json("/Users/timotheesanchez/Desktop/Behavior_analysis/data/DF_KRUSKAL_NIy_{}.json".format(date))

# %%
def mannwhitney_over_df(DF_time_list_NIx,gen1,gen2):
    data_gen1 = DF_time_list_NIx[gen1]
    data_gen2 = DF_time_list_NIx[gen2]
    pval = stats.mannwhitneyu(x= data_gen1,y=data_gen2,nan_policy="omit").pvalue
    return(pval)

# %%
arr_t = [str(t) for t in range(min_t,max_t,step_t)]
#print(arr_t)
arr_to = [str(to) for to in range(min_to,max_to,step_to)]
#print(arr_to)

gen_to_keep = ['FCF_attP2-40',
 'GMR_MB054B',
 'GMR_MB065B',
 'GMR_MB143B',
 'GMR_MB145B',
 'GMR_SS00864',
 'GMR_SS01696',
 'GMR_SS01716',
 'GMR_SS01757',
 'GMR_SS01948',
 'GMR_SS02160']

gen_to_test = [#'FCF_attP2-40',
 'GMR_MB054B',
 'GMR_MB065B',
 'GMR_MB143B',
 #'GMR_MB145B',
 'GMR_SS00864',
 'GMR_SS01696',
 #'GMR_SS01716',
 'GMR_SS01757',
 'GMR_SS01948'
 #'GMR_SS02160'
 ]

date_to_keep = ['20240219',
        '20240223',
        #'20240226',
        '20240301',
        '20240304',
        '20240308']

DF_NIx = DF_NI_condition(df_time,date_to_select=date_to_keep,genotype_to_select=gen_to_keep,arr_to=arr_to,arr_t = arr_t,axis= "x")
for gen in gen_to_test:
    DF_compressed_NIx = apply_NI(DF_NIx,mannwhitney_over_df,arr_t,arr_to,gen1 = "FCF_attP2-40",gen2 = gen)
    DF_compressed_NIx.to_json("/Users/timotheesanchez/Desktop/Behavior_analysis/data/DF_MannWith_NIx_w_control_{}.json".format(gen))

# %%
def shapiro_over_df(df_NIx_concat,gen):
    arr_gen = df_NIx_concat[gen]
    result = stats.shapiro(arr_gen)
    return(result.pvalue)

# %%
gen_to_keep = ['FCF_attP2-40',
 'GMR_MB054B',
 'GMR_MB065B',
 'GMR_MB143B',
 'GMR_MB145B',
 'GMR_SS00864',
 'GMR_SS01696',
 'GMR_SS01716',
 'GMR_SS01757',
 'GMR_SS01948',
 'GMR_SS02160']

for gen in gen_to_keep:
    DF_compressed_NIx = apply_NI(DF_NIx,shapiro_over_df,arr_t,arr_to,gen = gen)
    DF_compressed_NIx.to_json("/Users/timotheesanchez/Desktop/Behavior_analysis/data/DF_Shapiro_{}.json".format(gen))

# %% [markdown]
# ***
#
# # Analysis for the presentation

# %%
def compute_mean_one_gen_df(df_time_trunc, gen):
    arr_gen = df_time_trunc[gen]
    mean = arr_gen.mean()
    return mean

# %%
def compute_sem_one_gen_df(df_time_trunc, gen):
    arr_gen = df_time_trunc[gen]
    mean = arr_gen.sem()
    return mean

# %%
def diff_mean_genotypes(df_time_trunc, gen1, gen2):
    arr_gen1 = df_time_trunc[gen1] #usually control 
    arr_gen2 = df_time_trunc[gen2]
    mean_gen1 = arr_gen1.mean()
    mean_gen2 = arr_gen2.mean()
    diff = mean_gen1 - mean_gen2 
    return diff

# %%
arr_t = [str(t) for t in range(min_t,max_t,step_t)]
#print(arr_t)
arr_to = [str(to) for to in range(min_to,max_to,step_to)]
#print(arr_to)

gen_to_keep = ['FCF_attP2-40',
 'GMR_MB054B',
 'GMR_MB065B',
 'GMR_MB143B',
 'GMR_MB145B',
 'GMR_SS00864',
 'GMR_SS01696',
 'GMR_SS01716',
 'GMR_SS01757',
 'GMR_SS01948',
 'GMR_SS02160']

date_to_keep = ['20240219',
        '20240223',
        #'20240226',
        '20240301',
        '20240304',
        '20240308']

DF_NIx = DF_NI_condition(df_time,date_to_select=date_to_keep,genotype_to_select=gen_to_keep,arr_to=arr_to,arr_t = arr_t,axis= "x")

# %%
#Compute the mean

gen_to_test = ['FCF_attP2-40',
 'GMR_MB054B',
 'GMR_MB065B',
 'GMR_MB143B',
 'GMR_MB145B',
 'GMR_SS00864',
 'GMR_SS01696',
 'GMR_SS01716',
 'GMR_SS01757',
 'GMR_SS01948',
 'GMR_SS02160'
 ]

for genotype in gen_to_test:
    DF_compressed_NIx = apply_NI(DF_NIx,compute_sem_one_gen_df,arr_t,arr_to,gen = genotype)
    DF_compressed_NIx.to_json("/Users/timotheesanchez/Desktop/Behavior_analysis/data/DF_sem_NIx_wout2602_{}.json".format(genotype))

# %%
#Compute the mean

gen_to_test = [#'FCF_attP2-40',
 'GMR_MB054B',
 'GMR_MB065B',
 'GMR_MB143B',
 'GMR_MB145B',
 'GMR_SS00864',
 'GMR_SS01696',
 'GMR_SS01716',
 'GMR_SS01757',
 'GMR_SS01948',
 'GMR_SS02160'
 ]

for genotype in gen_to_test:
    DF_compressed_NIx = apply_NI(DF_NIx,diff_mean_genotypes,arr_t,arr_to,gen1 = "FCF_attP2-40",gen2= genotype)
    DF_compressed_NIx.to_json("/Users/timotheesanchez/Desktop/Behavior_analysis/data/DF_diff_NIx_wout2602_{}.json".format(genotype))

# %%
def mean_by_date_one_gen(df_time_trunc,gen):
    arr_gen = df_time_trunc[gen]
    mean_arr = arr_gen.mean()
    return mean_arr

# %%
arr_t = [str(t) for t in range(min_t,max_t,step_t)]
#print(arr_t)
arr_to = [str(to) for to in range(min_to,max_to,step_to)]
#print(arr_to)

gen_to_keep = ['FCF_attP2-40',
 'GMR_MB054B',
 'GMR_MB065B',
 'GMR_MB143B',
 'GMR_MB145B',
 'GMR_SS00864',
 'GMR_SS01696',
 'GMR_SS01716',
 'GMR_SS01757',
 'GMR_SS01948',
 'GMR_SS02160']

date_to_keep_list = ['20240219',
        '20240223',
        '20240226',
        '20240301',
        '20240304',
        '20240308']

for date in date_to_keep_list:
    date_to_keep = [date]
    DF_NIx = DF_NI_condition(df_time,date_to_keep,gen_to_keep,arr_to,arr_t,"x")
    DF_KRUSKAL_NIx = apply_NI(DF_NIx,mean_by_date_one_gen,arr_t,arr_to,gen="FCF_attP2-40")
    DF_KRUSKAL_NIx.to_json("/Users/timotheesanchez/Desktop/Behavior_analysis/data/DF_MEAN_FCF_by_DATE_{}.json".format(date))
